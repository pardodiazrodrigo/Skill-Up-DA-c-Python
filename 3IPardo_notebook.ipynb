# %% [markdown]
# - La notebook debe analizar las siguientes universidades (grupo I):
# >    - Universidad Nacional De Jujuy
# >    - Universidad de Moron
# - Trabajar creando gráficos que expliquen las siguientes dimensiones:
# > * Carrera
# > * Edad
# > * Género
# > * Localidad
# - Realizar un comparativo de inscripciones entre ambas universidades.
#
# - Presentar una conclusión final de lo analizado.

# %% [markdown]
# # 1. Universidad Nacional de Jujuy

# %%
import pandas as pd
import matplotlib as plt

df_jujuy = pd.read_csv("datasets/3IUNJujuy_process.txt", sep='\t')

# %% [markdown]
# ### Cantidad de inscriptos por carrera:

# %%
df_career = df_jujuy.pivot_table(index='career', 
                          aggfunc='count', 
                          values='university')
df_career.rename(columns={"university": "count by career"}, inplace=True)
df_career.sort_values(by='count by career', ascending=False, inplace=True)
df_career.reset_index(inplace=True)
df_career
# Out:
#                                                career  count by career
# 0                                            medicina               47
# 1                                           agronomía               46
# 2                              ingeniería electrónica               44
# 3                                 ingeniería mecánica               44
# 4                                          bioquímica               43
# 5            licenciatura en gestión de agroalimentos               43
# 6   licenciatura en planificación y diseño del pai...               42
# 7                                    contador público               41
# 8              licenciatura en relaciones del trabajo               41
# 9                       licenciatura en musicoterapia               41
# 10                             técnico para bioterios               40
# 11                          ingeniería en informática               39
# 12                licenciatura en ciencias biológicas               39
# 13                licenciatura en terapia ocupacional               37
# 14           licenciatura en kinesiología y fisiatría               37
# 15               licenciatura en ciencias ambientales               37
# 16         licenciatura en ciencias de la computación               36
# 17           licenciatura en ciencias de la educación               36
# 18                licenciatura en ciencias geológicas               36
# 19          licenciatura en producción de bioimagenes               36
# 20  licenciatura en ciencia y tecnología de alimentos               35
# 21                                  diseño industrial               33
# 22                   licenciatura en ciencia política               33
# 23                         licenciatura en psicología               32
# 24                                           farmacia               31
# 25                                           actuario               31
# 26            licenciatura en ciencias antropológicas               30
# 27                          diseño de imagen y sonido               30
# 28                         licenciatura en sociología               30
# 29                                       arquitectura               29
# 30                     licenciatura en administración               27
# 31                              ciencias veterinarias               22
# 32                              licenciatura en artes               20

# %% [markdown]
# ### Edad promedio por carrera:

# %%
df_age = df_jujuy.pivot_table(index='career', 
                          aggfunc='mean', 
                          values='age')
df_age.rename(columns={"age": "mean age"}, inplace=True)
df_age.sort_values(by='mean age', ascending=False, inplace=False)
df_age.reset_index(inplace=True)
df_age.style.format(precision=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_db689">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db689_level0_col0" class="col_heading level0 col0" >career</th>
#       <th id="T_db689_level0_col1" class="col_heading level0 col1" >mean age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db689_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db689_row0_col0" class="data row0 col0" >actuario</td>
#       <td id="T_db689_row0_col1" class="data row0 col1" >49.2</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_db689_row1_col0" class="data row1 col0" >agronomía</td>
#       <td id="T_db689_row1_col1" class="data row1 col1" >54.2</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_db689_row2_col0" class="data row2 col0" >arquitectura</td>
#       <td id="T_db689_row2_col1" class="data row2 col1" >53.3</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_db689_row3_col0" class="data row3 col0" >bioquímica</td>
#       <td id="T_db689_row3_col1" class="data row3 col1" >52.1</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_db689_row4_col0" class="data row4 col0" >ciencias veterinarias</td>
#       <td id="T_db689_row4_col1" class="data row4 col1" >61.5</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_db689_row5_col0" class="data row5 col0" >contador público</td>
#       <td id="T_db689_row5_col1" class="data row5 col1" >60.1</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_db689_row6_col0" class="data row6 col0" >diseño de imagen y sonido</td>
#       <td id="T_db689_row6_col1" class="data row6 col1" >58.2</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_db689_row7_col0" class="data row7 col0" >diseño industrial</td>
#       <td id="T_db689_row7_col1" class="data row7 col1" >47.6</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_db689_row8_col0" class="data row8 col0" >farmacia</td>
#       <td id="T_db689_row8_col1" class="data row8 col1" >58.4</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_db689_row9_col0" class="data row9 col0" >ingeniería electrónica</td>
#       <td id="T_db689_row9_col1" class="data row9 col1" >50.7</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_db689_row10_col0" class="data row10 col0" >ingeniería en informática</td>
#       <td id="T_db689_row10_col1" class="data row10 col1" >56.3</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_db689_row11_col0" class="data row11 col0" >ingeniería mecánica</td>
#       <td id="T_db689_row11_col1" class="data row11 col1" >55.5</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_db689_row12_col0" class="data row12 col0" >licenciatura en administración</td>
#       <td id="T_db689_row12_col1" class="data row12 col1" >58.9</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_db689_row13_col0" class="data row13 col0" >licenciatura en artes</td>
#       <td id="T_db689_row13_col1" class="data row13 col1" >52.0</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_db689_row14_col0" class="data row14 col0" >licenciatura en ciencia política</td>
#       <td id="T_db689_row14_col1" class="data row14 col1" >50.0</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_db689_row15_col0" class="data row15 col0" >licenciatura en ciencia y tecnología de alimentos</td>
#       <td id="T_db689_row15_col1" class="data row15 col1" >59.3</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_db689_row16_col0" class="data row16 col0" >licenciatura en ciencias ambientales</td>
#       <td id="T_db689_row16_col1" class="data row16 col1" >54.7</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_db689_row17_col0" class="data row17 col0" >licenciatura en ciencias antropológicas</td>
#       <td id="T_db689_row17_col1" class="data row17 col1" >53.9</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_db689_row18_col0" class="data row18 col0" >licenciatura en ciencias biológicas</td>
#       <td id="T_db689_row18_col1" class="data row18 col1" >53.2</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_db689_row19_col0" class="data row19 col0" >licenciatura en ciencias de la computación</td>
#       <td id="T_db689_row19_col1" class="data row19 col1" >56.1</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_db689_row20_col0" class="data row20 col0" >licenciatura en ciencias de la educación</td>
#       <td id="T_db689_row20_col1" class="data row20 col1" >50.7</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_db689_row21_col0" class="data row21 col0" >licenciatura en ciencias geológicas</td>
#       <td id="T_db689_row21_col1" class="data row21 col1" >54.1</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_db689_row22_col0" class="data row22 col0" >licenciatura en gestión de agroalimentos</td>
#       <td id="T_db689_row22_col1" class="data row22 col1" >52.9</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_db689_row23_col0" class="data row23 col0" >licenciatura en kinesiología y fisiatría</td>
#       <td id="T_db689_row23_col1" class="data row23 col1" >55.3</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_db689_row24_col0" class="data row24 col0" >licenciatura en musicoterapia</td>
#       <td id="T_db689_row24_col1" class="data row24 col1" >50.7</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_db689_row25_col0" class="data row25 col0" >licenciatura en planificación y diseño del paisaje</td>
#       <td id="T_db689_row25_col1" class="data row25 col1" >53.1</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_db689_row26_col0" class="data row26 col0" >licenciatura en producción de bioimagenes</td>
#       <td id="T_db689_row26_col1" class="data row26 col1" >55.7</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_db689_row27_col0" class="data row27 col0" >licenciatura en psicología</td>
#       <td id="T_db689_row27_col1" class="data row27 col1" >59.8</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_db689_row28_col0" class="data row28 col0" >licenciatura en relaciones del trabajo</td>
#       <td id="T_db689_row28_col1" class="data row28 col1" >53.2</td>
#     </tr>
#     <tr>
#       <th id="T_db689_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_db689_row29_col0" class="data row29 col0" >licenciatura en sociología</td>
#       <td id="T_db689_row29_col1" class="data row29 col1" >60.2</td>

# %% [markdown]
# ### Cantidad de hombres y mujeres por carrera:

# %%
df_gen = df_jujuy.groupby(["gender", 'career'])['university'].count()
df_gen = df_gen.to_frame()
df_gen.reset_index(inplace=True)
df_gen.rename(columns={"university": "count_by_career"}, inplace=True)
df_gen.sort_values(by=["gender", "count_by_career"], ascending=False, inplace=False)
df_gen
# Out:
#     gender                                  career  count_by_career
# 0   female                                actuario               10
# 1   female                               agronomía               21
# 2   female                            arquitectura               14
# 3   female                              bioquímica               20
# 4   female                   ciencias veterinarias                8
# ..     ...                                     ...              ...
# 61    male  licenciatura en relaciones del trabajo               19
# 62    male              licenciatura en sociología               18
# 63    male     licenciatura en terapia ocupacional               22
# 64    male                                medicina               27
# 65    male                  técnico para bioterios               19
#
# [66 rows x 3 columns]

# %% [markdown]
# ### Cantidad de personas inscriptas por localidad:

# %%
df_loc = df_jujuy.pivot_table(index='location', 
                          aggfunc='count', 
                          values='university')
df_loc.rename(columns={"university": "count by location"}, inplace=True)
df_loc.sort_values(by='count by location', ascending=False, inplace=True)
df_loc.reset_index(inplace=True)
df_loc
# Out:
#                     location  count by location
# 0                 25 de mayo                  6
# 1                bella vista                  5
# 2                     anguil                  5
# 3                  1 de mayo                  4
# 4    campo moises seccion 1a                  4
# ..                       ...                ...
# 796           cañada la rica                  1
# 797               alto lindo                  1
# 798        alto los cardales                  1
# 799      cañada de las vacas                  1
# 800         zona delta tigre                  1
#
# [801 rows x 2 columns]

# %% [markdown]
# # 1. Universidad Nacional de Moron

# %%
df_moron = pd.read_csv("datasets/3IUNMoron_process.txt", sep='\t')

# %% [markdown]
# ### Cantidad de inscriptos por carrera:

# %%
df_career = df_moron.pivot_table(index='career', 
                          aggfunc='count', 
                          values='university')
df_career.rename(columns={"university": "count by career"}, inplace=True)
df_career.sort_values(by='count by career', ascending=False, inplace=True)
df_career.reset_index(inplace=True)
df_career
# Out:
#                                                career  count by career
# 0             licenciatura en ciencias antropológicas               47
# 1   licenciatura en planificación y diseño del pai...               45
# 2                           ingeniería en informática               45
# 3                 licenciatura en ciencias geológicas               43
# 4          licenciatura en ciencias de la computación               43
# 5              licenciatura en relaciones del trabajo               42
# 6                          licenciatura en psicología               41
# 7            licenciatura en kinesiología y fisiatría               41
# 8                                        arquitectura               40
# 9                                          bioquímica               39
# 10                                   contador público               39
# 11                licenciatura en ciencias biológicas               39
# 12                         licenciatura en sociología               38
# 13                                           medicina               37
# 14  licenciatura en ciencia y tecnología de alimentos               37
# 15                                          agronomía               36
# 16                              ciencias veterinarias               36
# 17                   licenciatura en ciencia política               35
# 18                                  diseño industrial               35
# 19                      licenciatura en musicoterapia               34
# 20                                ingeniería mecánica               33
# 21                             ingeniería electrónica               33
# 22           licenciatura en gestión de agroalimentos               33
# 23                              licenciatura en artes               32
# 24           licenciatura en ciencias de la educación               32
# 25                                           farmacia               32
# 26                     licenciatura en administración               31
# 27          licenciatura en producción de bioimagenes               31
# 28                             técnico para bioterios               31
# 29                          diseño de imagen y sonido               30
# 30                                           actuario               29
# 31               licenciatura en ciencias ambientales               28
# 32                licenciatura en terapia ocupacional               26

# %% [markdown]
# ### Edad promedio por carrera:

# %%
df_age = df_moron.pivot_table(index='career', 
                          aggfunc='mean', 
                          values='age')
df_age.rename(columns={"age": "mean age"}, inplace=True)
df_age.sort_values(by='mean age', ascending=False, inplace=False)
df_age.reset_index(inplace=True)
df_age.style.format(precision=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0365d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0365d_level0_col0" class="col_heading level0 col0" >career</th>
#       <th id="T_0365d_level0_col1" class="col_heading level0 col1" >mean age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0365d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0365d_row0_col0" class="data row0 col0" >actuario</td>
#       <td id="T_0365d_row0_col1" class="data row0 col1" >46.8</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0365d_row1_col0" class="data row1 col0" >agronomía</td>
#       <td id="T_0365d_row1_col1" class="data row1 col1" >49.2</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0365d_row2_col0" class="data row2 col0" >arquitectura</td>
#       <td id="T_0365d_row2_col1" class="data row2 col1" >57.2</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0365d_row3_col0" class="data row3 col0" >bioquímica</td>
#       <td id="T_0365d_row3_col1" class="data row3 col1" >54.2</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0365d_row4_col0" class="data row4 col0" >ciencias veterinarias</td>
#       <td id="T_0365d_row4_col1" class="data row4 col1" >57.6</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0365d_row5_col0" class="data row5 col0" >contador público</td>
#       <td id="T_0365d_row5_col1" class="data row5 col1" >49.7</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0365d_row6_col0" class="data row6 col0" >diseño de imagen y sonido</td>
#       <td id="T_0365d_row6_col1" class="data row6 col1" >58.6</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0365d_row7_col0" class="data row7 col0" >diseño industrial</td>
#       <td id="T_0365d_row7_col1" class="data row7 col1" >49.4</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0365d_row8_col0" class="data row8 col0" >farmacia</td>
#       <td id="T_0365d_row8_col1" class="data row8 col1" >50.4</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0365d_row9_col0" class="data row9 col0" >ingeniería electrónica</td>
#       <td id="T_0365d_row9_col1" class="data row9 col1" >53.5</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0365d_row10_col0" class="data row10 col0" >ingeniería en informática</td>
#       <td id="T_0365d_row10_col1" class="data row10 col1" >56.2</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0365d_row11_col0" class="data row11 col0" >ingeniería mecánica</td>
#       <td id="T_0365d_row11_col1" class="data row11 col1" >54.2</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0365d_row12_col0" class="data row12 col0" >licenciatura en administración</td>
#       <td id="T_0365d_row12_col1" class="data row12 col1" >55.4</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0365d_row13_col0" class="data row13 col0" >licenciatura en artes</td>
#       <td id="T_0365d_row13_col1" class="data row13 col1" >55.3</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0365d_row14_col0" class="data row14 col0" >licenciatura en ciencia política</td>
#       <td id="T_0365d_row14_col1" class="data row14 col1" >57.3</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0365d_row15_col0" class="data row15 col0" >licenciatura en ciencia y tecnología de alimentos</td>
#       <td id="T_0365d_row15_col1" class="data row15 col1" >54.1</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0365d_row16_col0" class="data row16 col0" >licenciatura en ciencias ambientales</td>
#       <td id="T_0365d_row16_col1" class="data row16 col1" >59.4</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0365d_row17_col0" class="data row17 col0" >licenciatura en ciencias antropológicas</td>
#       <td id="T_0365d_row17_col1" class="data row17 col1" >57.1</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0365d_row18_col0" class="data row18 col0" >licenciatura en ciencias biológicas</td>
#       <td id="T_0365d_row18_col1" class="data row18 col1" >52.4</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0365d_row19_col0" class="data row19 col0" >licenciatura en ciencias de la computación</td>
#       <td id="T_0365d_row19_col1" class="data row19 col1" >54.2</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_0365d_row20_col0" class="data row20 col0" >licenciatura en ciencias de la educación</td>
#       <td id="T_0365d_row20_col1" class="data row20 col1" >55.3</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_0365d_row21_col0" class="data row21 col0" >licenciatura en ciencias geológicas</td>
#       <td id="T_0365d_row21_col1" class="data row21 col1" >54.1</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_0365d_row22_col0" class="data row22 col0" >licenciatura en gestión de agroalimentos</td>
#       <td id="T_0365d_row22_col1" class="data row22 col1" >51.4</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_0365d_row23_col0" class="data row23 col0" >licenciatura en kinesiología y fisiatría</td>
#       <td id="T_0365d_row23_col1" class="data row23 col1" >56.5</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_0365d_row24_col0" class="data row24 col0" >licenciatura en musicoterapia</td>
#       <td id="T_0365d_row24_col1" class="data row24 col1" >53.5</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_0365d_row25_col0" class="data row25 col0" >licenciatura en planificación y diseño del paisaje</td>
#       <td id="T_0365d_row25_col1" class="data row25 col1" >52.8</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_0365d_row26_col0" class="data row26 col0" >licenciatura en producción de bioimagenes</td>
#       <td id="T_0365d_row26_col1" class="data row26 col1" >53.5</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_0365d_row27_col0" class="data row27 col0" >licenciatura en psicología</td>
#       <td id="T_0365d_row27_col1" class="data row27 col1" >56.3</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_0365d_row28_col0" class="data row28 col0" >licenciatura en relaciones del trabajo</td>
#       <td id="T_0365d_row28_col1" class="data row28 col1" >62.1</td>
#     </tr>
#     <tr>
#       <th id="T_0365d_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_0365d_row29_col0" class="data row29 col0" >licenciatura en sociología</td>
#       <td id="T_0365d_row29_col1" class="data row29 col1" >54.5</td>

# %% [markdown]
# ### Cantidad de hombres y mujeres por carrera:

# %%
df_gen = df_jujuy.groupby(["gender", 'career'])['university'].count()
df_gen = df_gen.to_frame()
df_gen.reset_index(inplace=True)
df_gen.rename(columns={"university": "count_by_career"}, inplace=True)
df_gen.sort_values(by=["gender", "count_by_career"], ascending=False, inplace=False)
df_gen
# Out:
#     gender                                  career  count_by_career
# 0   female                                actuario               10
# 1   female                               agronomía               21
# 2   female                            arquitectura               14
# 3   female                              bioquímica               20
# 4   female                   ciencias veterinarias                8
# ..     ...                                     ...              ...
# 61    male  licenciatura en relaciones del trabajo               19
# 62    male              licenciatura en sociología               18
# 63    male     licenciatura en terapia ocupacional               22
# 64    male                                medicina               27
# 65    male                  técnico para bioterios               19
#
# [66 rows x 3 columns]

# %% [markdown]
# ### Cantidad de personas inscriptas por localidad:

# %%
df_loc = df_jujuy.pivot_table(index='location', 
                          aggfunc='count', 
                          values='university')
df_loc.rename(columns={"university": "count by location"}, inplace=True)
df_loc.sort_values(by='count by location', ascending=False, inplace=True)
df_loc.reset_index(inplace=True)
df_loc
# Out:
#                     location  count by location
# 0                 25 de mayo                  6
# 1                bella vista                  5
# 2                     anguil                  5
# 3                  1 de mayo                  4
# 4    campo moises seccion 1a                  4
# ..                       ...                ...
# 796           cañada la rica                  1
# 797               alto lindo                  1
# 798        alto los cardales                  1
# 799      cañada de las vacas                  1
# 800         zona delta tigre                  1
#
# [801 rows x 2 columns]
